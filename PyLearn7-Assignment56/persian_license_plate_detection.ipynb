# %%
# !pip install -q ultralytics
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.2/882.2 kB 8.8 MB/s eta 0:00:00

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Load a model
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 133MB/s]

# %%
model.train(data="/content/drive/MyDrive/Colab Notebooks/PyLearn7-Assignment56/data.yaml", epochs=30)
# Out:
# Ultralytics 8.3.7 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
my_model = YOLO("/content/runs/detect/train/weights/best.pt")

# %% [markdown]
# ### inference

# %%
my_model = YOLO("/content/best.pt")

# %%
result_1 = my_model("/content/drive/MyDrive/Colab Notebooks/PyLearn7-Assignment56/test_images/64_jpg.rf.1eb13a5cf4a05f6a6ff35680dd96702b.jpg", save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/PyLearn7-Assignment56/test_images/64_jpg.rf.1eb13a5cf4a05f6a6ff35680dd96702b.jpg: 640x640 2 License-Plates, 10.2ms
# Speed: 2.6ms preprocess, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
import cv2
import matplotlib.pyplot as plt

image_1 = cv2.imread("/content/runs/detect/predict/64_jpg.rf.1eb13a5cf4a05f6a6ff35680dd96702b.jpg")
image_1 = cv2.cvtColor(image_1 , cv2.COLOR_BGR2RGB)
plt.imshow(image_1)

# %%
result_2 = my_model("/content/drive/MyDrive/Colab Notebooks/PyLearn7-Assignment56/test_images/216__jpg.rf.71e7aebf636e6544b0562e582754b1b3.jpg", save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/PyLearn7-Assignment56/test_images/216__jpg.rf.71e7aebf636e6544b0562e582754b1b3.jpg: 640x640 3 License-Plates, 7.6ms
# Speed: 1.9ms preprocess, 7.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
image_2 = cv2.imread("/content/runs/detect/predict/216__jpg.rf.71e7aebf636e6544b0562e582754b1b3.jpg")
image_2 = cv2.cvtColor(image_2 , cv2.COLOR_BGR2RGB)
plt.imshow(image_2)

# %%
result_3 = my_model("/content/drive/MyDrive/Colab Notebooks/PyLearn7-Assignment56/test1.jpg", save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/PyLearn7-Assignment56/test1.jpg: 384x640 5 License-Plates, 446.5ms
# Speed: 18.9ms preprocess, 446.5ms inference, 37.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict

# %%
image_3 = cv2.imread("/content/runs/detect/predict/test1.jpg")
image_3 = cv2.cvtColor(image_3 , cv2.COLOR_BGR2RGB)
plt.imshow(image_3)

# %%
result_4 = my_model("/content/drive/MyDrive/Colab Notebooks/PyLearn7-Assignment56/test2.jpg", save=True)
# Out:
# image 1/1 /content/drive/MyDrive/Colab Notebooks/PyLearn7-Assignment56/test2.jpg: 480x640 2 License-Plates, 191.3ms
# Speed: 3.7ms preprocess, 191.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict

# %%
image_4 = cv2.imread("/content/runs/detect/predict/test2.jpg")
image_4 = cv2.cvtColor(image_4 , cv2.COLOR_BGR2RGB)
plt.imshow(image_4)
